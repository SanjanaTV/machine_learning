# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('/content/drive/MyDrive/Python/Dataset/seattle-weather (1).csv')
df
# Out:
#             date  precipitation  temp_max  temp_min  wind  weather
# 0     2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1     2012-01-02           10.9      10.6       2.8   4.5     rain
# 2     2012-01-03            0.8      11.7       7.2   2.3     rain
# 3     2012-01-04           20.3      12.2       5.6   4.7     rain
# 4     2012-01-05            1.3       8.9       2.8   6.1     rain
# ...          ...            ...       ...       ...   ...      ...
# 1456  2015-12-27            8.6       4.4       1.7   2.9     rain
# 1457  2015-12-28            1.5       5.0       1.7   1.3     rain
# 1458  2015-12-29            0.0       7.2       0.6   2.6      fog
# 1459  2015-12-30            0.0       5.6      -1.0   3.4      sun
# 1460  2015-12-31            0.0       5.6      -2.1   3.5      sun
#
# [1461 rows x 6 columns]

# %%
new_df=df.drop(['date'],axis='columns')
new_df
# Out:
#       precipitation  temp_max  temp_min  wind  weather
# 0               0.0      12.8       5.0   4.7  drizzle
# 1              10.9      10.6       2.8   4.5     rain
# 2               0.8      11.7       7.2   2.3     rain
# 3              20.3      12.2       5.6   4.7     rain
# 4               1.3       8.9       2.8   6.1     rain
# ...             ...       ...       ...   ...      ...
# 1456            8.6       4.4       1.7   2.9     rain
# 1457            1.5       5.0       1.7   1.3     rain
# 1458            0.0       7.2       0.6   2.6      fog
# 1459            0.0       5.6      -1.0   3.4      sun
# 1460            0.0       5.6      -2.1   3.5      sun
#
# [1461 rows x 5 columns]

# %%
x=new_df.drop('weather',axis='columns')
y=new_df['weather']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8)

# %%
model=RandomForestClassifier()
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
x_test
# Out:
#       precipitation  temp_max  temp_min  wind
# 1061            3.3      14.4      11.7   6.6
# 1099           10.2      10.6       3.3   4.5
# 677             0.0      13.3       7.2   4.1
# 389             5.8       7.2       1.1   2.6
# 170             1.0      19.4      10.0   3.0
# ...             ...       ...       ...   ...
# 569             0.0      31.1      13.9   3.0
# 180             0.3      21.7      15.0   1.9
# 249             0.0      28.3      14.4   4.2
# 55              0.0       7.2       2.8   6.4
# 456             0.0      17.2       8.3   3.6
#
# [293 rows x 4 columns]

# %%
x_train
# Out:
#       precipitation  temp_max  temp_min  wind
# 1069            3.0      12.8       6.7   3.1
# 979             0.0      32.2      15.0   2.9
# 371             2.0       7.2       2.8   3.0
# 817            22.1      11.7       7.2   3.9
# 1060            0.3      15.0      12.2   3.9
# ...             ...       ...       ...   ...
# 453             0.0      18.3       7.8   2.5
# 1380            4.6      18.3      10.6   2.8
# 595             0.0      26.1      15.6   3.1
# 880             0.0      20.6       8.9   4.5
# 948             0.0      26.1      15.0   2.2
#
# [1168 rows x 4 columns]

# %%
y_predicted=model.predict(x_test)

# %%
model.score(x_test,y_test)
# Out:
# 0.856655290102389

# %%
print(type('x_test'))
# Out:
# <class 'str'>

# %%
a=float(input('Precipitation: '))
b=float(input('Temp max: '))
c=float(input('Temp min: '))
d=float(input('Wind rate: '))
y_predicted=model.predict([[a,b,c,d]])
y_predicted
# Out:
# Precipitation: 22.0
# Temp max: 15.5
# Temp min: 5.5
# Wind rate: 2.5
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array(['rain'], dtype=object)
