# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/drive/MyDrive/Python/Dataset/insurance_data (1).csv")
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
# %matplotlib inline
plt.xlabel('axis')
plt.ylabel('price')
plt.scatter(df.area,df.price,color='red',marker='+')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-bdcad923360a> in <cell line: 4>()
#       2 plt.xlabel('axis')
#       3 plt.ylabel('price')
# ----> 4 plt.scatter(df.area,df.price,color='red',marker='+')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'area'

# %%
new_df=df.drop(['town','price'],axis='columns')
new_df

# %%
price=df.price
price

# %%
reg=DecisionTreeRegressor()
reg.fit(new_df,price)

# %%
reg.predict([[3300]])

# %%
reg.predict([[5000]])

# %%
x=int(input('Enter the area: '))
reg.predict([[x]])
