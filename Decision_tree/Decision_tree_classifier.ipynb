# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
from sklearn.tree import DecisionTreeClassifier

# %%
df=pd.read_csv("/content/drive/MyDrive/Python/Dataset/insurance_data (1).csv")

# %%
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(df[['age']],df.bought_insurance,train_size=0.8)

# %%
x_test
# Out:
#     age
# 16   25
# 23   45
# 18   19
# 25   54
# 11   28
# 19   18

# %%
x_train
# Out:
#     age
# 24   50
# 10   18
# 0    22
# 8    62
# 13   29
# 6    55
# 15   55
# 21   26
# 22   40
# 26   23
# 1    25
# 2    47
# 20   21
# 17   58
# 3    52
# 12   27
# 7    60
# 4    46
# 9    61
# 14   49
# 5    56

# %%
model=DecisionTreeClassifier()
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_predicted=model.predict(x_test)
model.predict_proba(x_test)
# Out:
# array([[1. , 0. ],
#        [0. , 1. ],
#        [1. , 0. ],
#        [0.5, 0.5],
#        [1. , 0. ],
#        [1. , 0. ]])

# %%
model.score(x_test,y_test)
# Out:
# 0.6666666666666666

# %%
y_predicted
# Out:
# array([0, 1, 0, 0, 0, 0])

# %%
x=int(input('enter the age: '))
df=pd.DataFrame([x], dtype=int)
y_predicted=model.predict([[x]])
y_predicted
# Out:
# enter the age: 35
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
#model.coef_ indicates value of m in y=m*x+b
#model.coef_

# %%
#model.intercept_   # indicates b in y=m*x+b

# %% [markdown]
# Dataset 2 (Kyphosis)

# %%
df2=pd.read_csv("/content/drive/MyDrive/Python/Dataset/kyphosis.csv")
df2
# Out:
#    Kyphosis  Age  Number  Start
# 0    absent   71       3      5
# 1    absent  158       3     14
# 2   present  128       4      5
# 3    absent    2       5      1
# 4    absent    1       4     15
# ..      ...  ...     ...    ...
# 76  present  157       3     13
# 77   absent   26       7     13
# 78   absent  120       2     13
# 79  present   42       7      6
# 80   absent   36       4     13
#
# [81 rows x 4 columns]

# %%
new_df2=df2.drop('Number',axis=1)
new_df2
# Out:
#    Kyphosis  Age  Start
# 0    absent   71      5
# 1    absent  158     14
# 2   present  128      5
# 3    absent    2      1
# 4    absent    1     15
# ..      ...  ...    ...
# 76  present  157     13
# 77   absent   26     13
# 78   absent  120     13
# 79  present   42      6
# 80   absent   36     13
#
# [81 rows x 3 columns]

# %%
new_df3=new_df2.drop('Start',axis=1)
new_df3
# Out:
#    Kyphosis  Age
# 0    absent   71
# 1    absent  158
# 2   present  128
# 3    absent    2
# 4    absent    1
# ..      ...  ...
# 76  present  157
# 77   absent   26
# 78   absent  120
# 79  present   42
# 80   absent   36
#
# [81 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(df2[['Age']],df2.Kyphosis,train_size=0.8)

# %%
x_test
# Out:
#     Age
# 71  127
# 10   82
# 19   27
# 53    2
# 66  195
# 8   113
# 77   26
# 40   73
# 54  140
# 22   96
# 15    1
# 36    1
# 67  159
# 2   128
# 52  139
# 4     1
# 74   11

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_predicted=model.predict(x_test)
model.predict_proba(x_test)
# Out:
# array([[0.78835432, 0.21164568],
#        [0.81682163, 0.18317837],
#        [0.84746692, 0.15253308],
#        [0.85994454, 0.14005546],
#        [0.73945647, 0.26054353],
#        [0.79754347, 0.20245653],
#        [0.84798306, 0.15201694],
#        [0.82214463, 0.17785537],
#        [0.77955163, 0.22044837],
#        [0.80829716, 0.19170284],
#        [0.86042541, 0.13957459],
#        [0.86042541, 0.13957459],
#        [0.76621958, 0.23378042],
#        [0.78768642, 0.21231358],
#        [0.78023798, 0.21976202],
#        [0.86042541, 0.13957459],
#        [0.85555408, 0.14444592]])

# %%
model.score(x_test,y_test)
# Out:
# 0.7058823529411765

# %%
y_predicted
# Out:
# array(['absent', 'absent', 'absent', 'absent', 'absent', 'absent',
#        'absent', 'absent', 'absent', 'absent', 'absent', 'absent',
#        'absent', 'absent', 'absent', 'absent', 'absent'], dtype=object)
