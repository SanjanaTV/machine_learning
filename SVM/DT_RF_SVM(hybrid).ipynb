# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC

# %%
df=pd.read_csv('/content/drive/MyDrive/Python/Dataset/diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
x=df.drop('Outcome',axis='columns')
y=df['Outcome']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8)

# %%
x_test
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 297            0      126             84             29      215  30.7
# 353            1       90             62             12       43  27.2
# 306           10      161             68             23      132  25.5
# 203            2       99             70             16       44  20.4
# 590           11      111             84             40        0  46.8
# ..           ...      ...            ...            ...      ...   ...
# 470            1      144             82             40        0  41.3
# 304            3      150             76              0        0  21.0
# 165            6      104             74             18      156  29.9
# 433            2      139             75              0        0  25.6
# 537            0       57             60              0        0  21.7
#
#      DiabetesPedigreeFunction  Age
# 297                     0.520   24
# 353                     0.580   24
# ...

# %%
x_train
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 538            0      127             80             37      210  36.3
# 181            0      119             64             18       92  34.9
# 539            3      129             92             49      155  36.4
# 334            1       95             60             18       58  23.9
# 183            5       73             60              0        0  26.8
# ..           ...      ...            ...            ...      ...   ...
# 188            8      109             76             39      114  27.9
# 316            3       99             80             11       64  19.3
# 649            0      107             60             25        0  26.4
# 27             1       97             66             15      140  23.2
# 490            2       83             65             28       66  36.8
#
#      DiabetesPedigreeFunction  Age
# 538                     0.804   23
# 181                     0.725   23
# ...

# %% [markdown]
# Using decision tree classifier

# %%
model=DecisionTreeClassifier()
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_predicted=model.predict(x_test)

# %%
print(type(x_test))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
model.score(x_test,y_test)
# Out:
# 0.6753246753246753

# %%
a=float(input('enter the glucose level during pregnancies: '))
b=float(input('enter the glucose level: '))
c=float(input('enter the BloodPressure: '))
d=float(input('enter the skin thickness: '))
e=float(input('enter the insulin: '))
f=float(input('BMI: '))
g=float(input('Diabetes Pedigree Function: '))
h=float(input('enter your age: '))
df=pd.DataFrame([[a],[b],[c],[d],[e],[f],[g],[h]], dtype=str)
y_predicted=model.predict([[a,b,c,d,e,f,g,h]])
x=[]
i=y_predicted
x.append(i)
print(i)  # 0	137	40	35	168	43.1	2.288	33   #1	89	66	23	94	28.1	0.167	21
# Out:
# enter the glucose level during pregnancies: 0
# enter the glucose level: 137
# enter the BloodPressure: 40
# enter the skin thickness: 35
# enter the insulin: 168
# BMI: 43.1
# Diabetes Pedigree Function: 2.288
# enter your age: 33
# [0]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# using random forest classifier

# %%
model=RandomForestClassifier()
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_predicted=model.predict(x_test)

# %%
model.score(x_test,y_test)
# Out:
# 0.7857142857142857

# %%
a=float(input('enter the glucose level during pregnancies: '))
b=float(input('enter the glucose level: '))
c=float(input('enter the BloodPressure: '))
d=float(input('enter the skin thickness: '))
e=float(input('enter theinsulin: '))
f=float(input('BMI: '))
g=float(input('Diabetes Pedigree Function: '))
h=float(input('enter your age: '))
df=pd.DataFrame([[a],[b],[c],[d],[e],[f],[g],[h]], dtype=str)
y_predicted=model.predict([[a,b,c,d,e,f,g,h]])
j=y_predicted
x.append(j)
print(j)  # 0	137	40	35	168	43.1	2.288	33   #1	89	66	23	94	28.1	0.167	21
# Out:
# enter the glucose level during pregnancies: 0
# enter the glucose level: 137
# enter the BloodPressure: 40
# enter the skin thickness: 35
# enter theinsulin: 168
# BMI: 43.1
# Diabetes Pedigree Function: 2.288
# enter your age: 33
# [1]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# using SVM classifier

# %%
model=SVC()
model.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_predicted=model.predict(x_test)

# %%
model.score(x_test,y_test)
# Out:
# 0.7402597402597403

# %%
a=float(input('enter the glucose level during pregnancies: '))
b=float(input('enter the glucose level: '))
c=float(input('enter the BloodPressure: '))
d=float(input('enter the skin thickness: '))
e=float(input('enter theinsulin: '))
f=float(input('BMI: '))
g=float(input('Diabetes Pedigree Function: '))
h=float(input('enter your age: '))
df=pd.DataFrame([[a],[b],[c],[d],[e],[f],[g],[h]], dtype=str)
y_predicted=model.predict([[a,b,c,d,e,f,g,h]])
k=y_predicted
x.append(k)   # 0	137	40	35	168	43.1	2.288	33   #1	89	66	23	94	28.1	0.167	21
print(k)
# Out:
# enter the glucose level during pregnancies: 0
# enter the glucose level: 137
# enter the BloodPressure: 40
# enter the skin thickness: 35
# enter theinsulin: 168
# BMI: 43.1
# Diabetes Pedigree Function: 2.288
# enter your age: 33
# [0]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
x
# Out:
# [array([0]), array([1]), array([0])]

# %%
if(x.count(1)>1):
  print('the person has diabetes')
else:
  print('the person has no diabetes')
# Out:
# the person has no diabetes
