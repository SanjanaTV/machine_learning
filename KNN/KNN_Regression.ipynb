# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsRegressor

# %%
df=pd.read_csv('/content/drive/MyDrive/Python/Dataset/travel_packages.csv')
df
# Out:
#       index                       place   price  \
# 0         0                      manali  18,699
# 1         1                   new delhi   4,999
# 2         2                   new delhi   4,999
# 3         3                      jaipur   6,100
# 4         4                      jaipur   6,100
# ...     ...                         ...     ...
# 1604   1604     bhutan winter  Packages  29,999
# 1605   1605  sri lanka winter  Packages  18,799
# 1606   1606     bhutan winter  Packages  22,500
# 1607   1607  sri lanka winter  Packages  15,999
# 1608   1608  hong kong winter  Packages  65,990
#
#                                                    time  \
# 0     \n                            6 NIGHTS\n      ...
# 1     \n                            2 NIGHTS\n      ...
# 2     \n                            2 NIGHTS\n      ...
# 3     \n                            2 NIGHTS\n      ...
# 4     \n                            2 NIGHTS\n      ...
# ...

# %%
new_df=df.drop(['index', 'about_trip','emi'], axis='columns')
new_df
# Out:
#                            place   price  \
# 0                         manali  18,699
# 1                      new delhi   4,999
# 2                      new delhi   4,999
# 3                         jaipur   6,100
# 4                         jaipur   6,100
# ...                          ...     ...
# 1604     bhutan winter  Packages  29,999
# 1605  sri lanka winter  Packages  18,799
# 1606     bhutan winter  Packages  22,500
# 1607  sri lanka winter  Packages  15,999
# 1608  hong kong winter  Packages  65,990
#
#                                                    time
# 0     \n                            6 NIGHTS\n      ...
# 1     \n                            2 NIGHTS\n      ...
# 2     \n                            2 NIGHTS\n      ...
# 3     \n                            2 NIGHTS\n      ...
# 4     \n                            2 NIGHTS\n      ...
# ...                                                 ...
# 1604  \n                            5 NIGHTS\n      ...
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
new_df['time']=le.fit_transform(new_df['time'])

# %%
class_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
print(class_mapping)
# Out:
# {'\n                            1 NIGHT\n                        ': 0, '\n                            10 NIGHTS\n                        ': 1, '\n                            11 NIGHTS\n                        ': 2, '\n                            12 NIGHTS\n                        ': 3, '\n                            13 NIGHTS\n                        ': 4, '\n                            14 NIGHTS\n                        ': 5, '\n                            15 NIGHTS\n                        ': 6, '\n                            16 NIGHTS\n                        ': 7, '\n                            17 NIGHTS\n                        ': 8, '\n                            19 NIGHTS\n                        ': 9, '\n                            2 NIGHTS\n                        ': 10, '\n                            3 NIGHTS\n                        ': 11, '\n                            4 NIGHTS\n                        ': 12, '\n                            5 NIGHTS\n                      
# ...

# %%
new_df.dtypes['time']
# Out:
# dtype('int64')

# %%
new_df.dtypes['price']
# Out:
# dtype('O')

# %%
#new_df['price']=new_df['price'].astype(int)

# %%
new_df['price']=pd.Series(new_df['price']).str.replace(',', '').astype(int)

# %%
new_df['price']
# Out:
# 0       18699
# 1        4999
# 2        4999
# 3        6100
# 4        6100
#         ...
# 1604    29999
# 1605    18799
# 1606    22500
# 1607    15999
# 1608    65990
# Name: price, Length: 1609, dtype: int64

# %%
new_df
# Out:
#       place  price  time
# 0       130  18699    14
# 1       154   4999    10
# 2       154   4999    10
# 3        91   6100    10
# 4        91   6100    10
# ...     ...    ...   ...
# 1604     23  29999    13
# 1605    208  18799    11
# 1606     23  22500    12
# 1607    208  15999    11
# 1608     81  65990    13
#
# [1609 rows x 3 columns]

# %%
new_df['place']=le.fit_transform(new_df['place'])

# %%
class_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
print(class_mapping)
# Out:
# {'aberdare': 0, 'abu dhabi': 1, 'agra': 2, 'alibag': 3, 'amman': 4, 'amritsar': 5, 'amsterdam': 6, 'andaman and nicobar islands': 7, 'andhra pradesh': 8, 'athens': 9, 'auckland': 10, 'australia': 11, 'austria': 12, 'bali': 13, 'bandipur': 14, 'banff': 15, 'bangkok': 16, 'barcelona': 17, 'belgium': 18, 'bengaluru': 19, 'bergen': 20, 'berlin': 21, 'bhutan': 22, 'bhutan winter  Packages': 23, 'bikaner': 24, 'bintan island': 25, 'brisbane': 26, 'brussels': 27, 'budapest': 28, 'cairns': 29, 'calgary': 30, 'cambodia': 31, 'canada': 32, 'cape town': 33, 'cappadocia': 34, 'chandigarh': 35, 'changla pass': 36, 'cherrapunji': 37, 'chiang mai': 38, 'chiang rai': 39, 'china': 40, 'chittorgarh': 41, 'christchurch': 42, 'cologne': 43, 'colombo': 44, 'coorg': 45, 'copenhagen': 46, 'corbett': 47, 'cordoba': 48, 'croatia': 49, 'czech republic': 50, 'dalhousie': 51, 'dead sea': 52, 'dharamshala': 53, 'dubai': 54, 'dublin': 55, 'dubrovnik': 56, 'egypt': 57, 'engelberg': 58, 'europe': 59, 'fiji': 60, 'f
# ...

# %%
new_df
# Out:
#       place  price  time
# 0       130  18699    14
# 1       154   4999    10
# 2       154   4999    10
# 3        91   6100    10
# 4        91   6100    10
# ...     ...    ...   ...
# 1604     23  29999    13
# 1605    208  18799    11
# 1606     23  22500    12
# 1607    208  15999    11
# 1608     81  65990    13
#
# [1609 rows x 3 columns]

# %%
x=new_df.drop('price',axis='columns')
y=new_df['price']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8)

# %%
model=KNeighborsRegressor(n_neighbors=5)
model.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
print(type(x_test))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
x_test
# Out:
#       place  time
# 1233     61     1
# 1334    107    14
# 450     225    16
# 1298     63    17
# 1278    234    15
# ...     ...   ...
# 1590    234    16
# 757     211    15
# 111       7    14
# 675     212    16
# 376      26    12
#
# [322 rows x 2 columns]

# %%
y_predicted=model.predict(x_test)

# %%
new_df.dtypes['price']
# Out:
# dtype('int64')

# %%
model.score(x_test,y_test)
# Out:
# 0.3508508125108756

# %%
print("""aberdare': 0, 'abu dhabi': 1, 'agra': 2, 'alibag': 3, 'amman': 4,
'amritsar': 5, 'amsterdam': 6, 'andaman and nicobar islands': 7,
'andhra pradesh': 8, 'athens': 9, 'auckland': 10""")
a=int(input('enter the place: '))
print("""1night:0 10night:1 11night:2 12night:3 13nights:4 14nights:5
 15night:6 16nights:7 17nights:8 19night:9 2night:10 3nights:11 4nights:12
  5nights:13 6nights:14 7nights:15 8nights:16 9nights:17""")
b=int(input("enter the time: "))
df=pd.DataFrame([[a],[b]], dtype=int)
y_predicted=model.predict([[a,b]])
print('the price is: ',y_predicted)
# Out:
# aberdare': 0, 'abu dhabi': 1, 'agra': 2, 'alibag': 3, 'amman': 4,
# 'amritsar': 5, 'amsterdam': 6, 'andaman and nicobar islands': 7,
# 'andhra pradesh': 8, 'athens': 9, 'auckland': 10
# enter the place: 5
# 1night:0 10night:1 11night:2 12night:3 13nights:4 14nights:5
#  15night:6 16nights:7 17nights:8 19night:9 2night:10 3nights:11 4nights:12
#   5nights:13 6nights:14 7nights:15 8nights:16 9nights:17
# enter the time: 6
# the price is:  [14399.2]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(
