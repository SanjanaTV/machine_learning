# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier

# %%
df=pd.read_csv('/content/drive/MyDrive/Python/Dataset/heart_disease_dataset.csv')
df
# Out:
#      age   BP  cholestrol  heart disease
# 0     70  130         322              1
# 1     67  115         564              0
# 2     57  124         261              1
# 3     64  128         263              0
# 4     74  120         269              0
# ..   ...  ...         ...            ...
# 265   52  172         199              0
# 266   44  120         263              0
# 267   56  140         294              0
# 268   57  140         192              0
# 269   67  160         286              1
#
# [270 rows x 4 columns]

# %%
x=df.drop('heart disease',axis='columns')
y=df['heart disease']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8)

# %%
model=KNeighborsClassifier(n_neighbors=5)
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_predicted=model.predict(x_test)

# %%
x_test
# Out:
#      age   BP  cholestrol
# 40    40  152         223
# 19    40  140         199
# 137   56  125         249
# 96    66  120         302
# 153   64  130         303
# 145   53  123         282
# 125   54  160         201
# 148   58  132         224
# 105   48  124         274
# 140   64  145         212
# 64    63  145         233
# 27    51  120         295
# 174   34  118         182
# 68    44  118         242
# 144   54  192         283
# 258   64  140         335
# 220   54  110         239
# 164   43  110         211
# 206   60  102         318
# 79    56  120         236
# 269   67  160         286
# 22    43  115         303
# 126   62  120         267
# 12    44  140         235
# 16    46  140         311
# 165   64  180         325
# 226   62  130         263
# 69    47  108         243
# 224   35  138         183
# 21    48  130         245
# 31    66  160         228
# 149   41  112         268
# 83    41  130         214
# 15    71  112         149
# ...

# %%
x_train
# Out:
#      age   BP  cholestrol
# 251   44  130         219
# 172   67  100         299
# 74    67  106         223
# 104   63  130         254
# 213   58  128         216
# ..   ...  ...         ...
# 197   54  110         214
# 215   41  130         204
# 131   66  112         212
# 242   53  130         264
# 233   52  128         255
#
# [216 rows x 3 columns]

# %%
model.score(x_test,y_test)
# Out:
# 0.5740740740740741

# %%
print(type(x_test))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
a=int(input("Enter the age: "))
b=int(input("Enter BP: "))
c=int(input("Enter Cholestrol: "))
df=pd.DataFrame([[a],[b],[c]], dtype=int)
y_predicted=model.predict([[a,b,c]])
print('Result: ',y_predicted)
# Out:
# Enter the age: 57
# Enter BP: 124
# Enter Cholestrol: 261
# Result:  [1]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
